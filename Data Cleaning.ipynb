# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
dirty_data = pd.read_csv ("C:/Users/kolaw/OneDrive/Documents/Alawadata/workdata.csv",sep='\t')

# %%
dirty_data
# Out:
#    Name,Age,Location,Phone,Email,Education,Experience,Marital_Status,Sex,Work_Experience,Qualification,Salary
# 0   Alice,25,New York,555-1234,alice.email.com,Bac...
# 1   Bob,,San Francisco,,bob.phone.com,,Master's,Ma...
# 2   Charlie,30,Chicago,(555)-5678,,,Bachelor's,3 y...
# 3   David,40,,,david.email.com,PhD,6 years,Single,...
# 4   Eve,28,Los Angeles,eve.phone.com,eve.email.com...
# 5   Frank,22,"",frank.email.com,,5 years,Single,Ma...
# 6   Grace,35,Miami,,grace.email.com,Master's,7 yea...
# 7   Henry,"45",San Diego,555-9876,henry.email.com,...
# 8   Isabel,28,Houston,,isabel.email.com,High Schoo...
# 9   Jack,,Boston,jack.phone.com,,Bachelor's,3 year...
# 10  Alice,25,New York,555-1234,alice.email.com,Bac...
# 11  Bob,,San Francisco,,bob.phone.com,,Master's,Ma...
# 12  Charlie,30,Chicago,(555)-5678,,,Bachelor's,3 y...
# 13  David,40,,,david.email.com,PhD,6 years,Single,...
# 14  Eve,28,Los Angeles,eve.phone.com,eve.email.com...
# ...

# %%
car_data = pd.read_csv ("C:/Users/kolaw/OneDrive/Documents/Alawadata/car_dataset.csv")

# %%
car_data
# Out:
#    Vehicle       Make    Model  Year   Color License Plate  Passengers
# 0      Car     Toyota    Camry  2015    Blue        ABC123           4
# 1      Car     Toyota    Camry  2015    Blue        ABC123           4
# 2     Bike      Honda  CRF250L  2020     Red        XYZ789           2
# 3      Bus       Ford  Transit  2010  Yellow        DEF456          20
# 4      Car       Ford    F-150  2019   Green        ABC123           4
# 5      Car  Chevrolet   Impala  2010     Red        GHI789           5
# 6     Bike   Kawasaki    Ninja  2018   Black        XYZ789           2
# 7      Car     Toyota  Corolla  2016    Blue        JKL123           5
# 8      Bus       Ford  Transit  2010  Yellow        DEF456          20
# 9     Bike      Honda  CRF250L  2020     Red        XYZ789           2
# 10     Car       Ford    F-150  2019   Green        ABC123           4
# 11     Car  Chevrolet   Impala  2010     Red        GHI789           5
# ...

# %%
car_data.shape
# Out:
# (15, 7)

# %%
car_data.shape
# Out:
# (15, 7)

# %%
dirty_data = pd.read_csv ("C:/Users/kolaw/OneDrive/Documents/Alawadata/workdata.csv",sep='\t')

# %%
dirty_data
# Out:
#    Name,Age,Location,Phone,Email,Education,Experience,Marital_Status,Sex,Work_Experience,Qualification,Salary
# 0   Alice,25,New York,555-1234,alice.email.com,Bac...
# 1   Bob,,San Francisco,,bob.phone.com,,Master's,Ma...
# 2   Charlie,30,Chicago,(555)-5678,,,Bachelor's,3 y...
# 3   David,40,,,david.email.com,PhD,6 years,Single,...
# 4   Eve,28,Los Angeles,eve.phone.com,eve.email.com...
# 5   Frank,22,"",frank.email.com,,5 years,Single,Ma...
# 6   Grace,35,Miami,,grace.email.com,Master's,7 yea...
# 7   Henry,"45",San Diego,555-9876,henry.email.com,...
# 8   Isabel,28,Houston,,isabel.email.com,High Schoo...
# 9   Jack,,Boston,jack.phone.com,,Bachelor's,3 year...
# 10  Alice,25,New York,555-1234,alice.email.com,Bac...
# 11  Bob,,San Francisco,,bob.phone.com,,Master's,Ma...
# 12  Charlie,30,Chicago,(555)-5678,,,Bachelor's,3 y...
# 13  David,40,,,david.email.com,PhD,6 years,Single,...
# 14  Eve,28,Los Angeles,eve.phone.com,eve.email.com...
# ...

# %%
for column in dirty_data.columns:
# Out:
#   Cell In[32], line 1
#     for column in dirty_data.columns:
#                                      ^
# SyntaxError: incomplete input

# %%
value = dirty_data

# %%
print (column)
# Out:
# Name,Age,Location,Phone,Email,Education,Experience,Marital_Status,Sex,Work_Experience,Qualification,Salary

# %%
for column in dirty_data.columns:
    print(column)
# Out:
# Name,Age,Location,Phone,Email,Education,Experience,Marital_Status,Sex,Work_Experience,Qualification,Salary

# %%
for column in dirty_data.columns:
    print(f"column:(column)")
    for vaue in dirty_data[column]:
        print(value)
        print()
# Out:
# column:(column)
#    Name,Age,Location,Phone,Email,Education,Experience,Marital_Status,Sex,Work_Experience,Qualification,Salary
# 0   Alice,25,New York,555-1234,alice.email.com,Bac...
# 1   Bob,,San Francisco,,bob.phone.com,,Master's,Ma...
# 2   Charlie,30,Chicago,(555)-5678,,,Bachelor's,3 y...
# 3   David,40,,,david.email.com,PhD,6 years,Single,...
# 4   Eve,28,Los Angeles,eve.phone.com,eve.email.com...
# 5   Frank,22,"",frank.email.com,,5 years,Single,Ma...
# 6   Grace,35,Miami,,grace.email.com,Master's,7 yea...
# 7   Henry,"45",San Diego,555-9876,henry.email.com,...
# 8   Isabel,28,Houston,,isabel.email.com,High Schoo...
# 9   Jack,,Boston,jack.phone.com,,Bachelor's,3 year...
# 10  Alice,25,New York,555-1234,alice.email.com,Bac...
# 11  Bob,,San Francisco,,bob.phone.com,,Master's,Ma...
# 12  Charlie,30,Chicago,(555)-5678,,,Bachelor's,3 y...
# 13  David,40,,,david.email.com,PhD,6 years,Single,...
# 14  Eve,28,Los Angeles,eve.phone.com,eve.email.com...
# ...
